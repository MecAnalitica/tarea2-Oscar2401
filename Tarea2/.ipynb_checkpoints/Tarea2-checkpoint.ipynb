# %% [markdown]
# # Oscar De la Cruz Echevetse

# %% [markdown]
# # Tarea 2: Mecánica Analítica

# %% [markdown]
# ## 1. El péndulo forzado amortiguado
#
# ## Instrucciones:
#
# La ecuación del péndulo forzado amortiguado es
#
#     Aceleración+Amortiguamiento+Gravedad=Fuerza externa
#
# Que como ecuación se ve:
#
# \begin{equation}
# \ddot \theta + \mu \dot\theta + sin(\theta) = Acos(\omega_d t)
# \end{equation}
#
# donde hemos normalizado el tiempo para que la frencuencia natural sea 1.
#
# Límite lineal. Considerando ángulos pequeños, tenemos la ecuación lineal forzada y amortiguada vista en clase, cuya solución particular tiene una función coseno con una cierta amplitud y fase dada en términos de los parametros de la ecuación anterior. Tomando $A=1$ y $\mu=0.05$

# %% [markdown]
# ## CODIGO

# %%
#librerias a usar 
import matplotlib. pyplot as plt
import numpy as np
import math
from scipy.integrate import odeint

# %% [markdown]
# ### Problemas a resolver:

# %% [markdown]
# ### a) Graficar la Amplitud como función de la frecuencia de la fuerza externa.

# %% [markdown]
# La solución particular vista en clase es:
#
# \begin{equation}
# \theta_p(t)=\frac{A}{\sqrt{(\omega_0^2-\omega_d^2)^2 + 4\omega_d^2\beta^2}} \cos(\omega_dt-\delta)
# \end{equation}
#
# Así definimos:
# \begin{equation}
# Amplitud = \frac{A}{\sqrt{(\omega_0^2-\omega_d^2)^2 + 4\omega_d^2\beta^2}}
# \end{equation}
#
# La cual defino como función en la siguiente linea de codigo:

# %%
#definimos función para la amplitud:
def amplitud (dat):
    omg = dat[0]  #frecuencia de la fuerza externa.
    mu = dat[1]  
    omg0 = dat[2] #frencuencia natural
    arg = pow(pow(pow(omg0,2)-pow(omg,2),2)+pow(omg*mu,2),0.5)
    return np.divide( 1 , arg )

# %% [markdown]
# Donde, en este caso: $\mu=2\beta=0.05$, $\omega_0=1$ y $A=1$.
#
# \begin{equation}
# Amplitud = \frac{1}{\sqrt{(1-\omega_d^2)^2 + \omega_d^2\mu^2}}
# \end{equation}
#
# Así calculamos la amplitud en las siguientes líneas de codigo:

# %%
omg_0 = 1 # frecuencia natural
mu = 0.05
ffe = np.linspace(omg_0 - 1, omg_0 + 2, 10000) #ffe = frecuencia de la fuerza externa entre la frecuencia natural y mayor a cero.
dats = np.array([ffe , mu , omg_0])
amp = amplitud(dats)

# %% [markdown]
# La gráfica de la Amplitud como función de la frecuencia de la fuerza externa se verá como:

# %%
plt.figure(figsize=(10,8))
plt.xlim(np.amin(ffe),np.amax(ffe))

plt.subplot(2, 1, 1)
plt.title('(1.a) Amplutud Vs. frecuencia de la fuerza externa',fontsize = 28, color = '0', verticalalignment = 'baseline', horizontalalignment = 'center')
plt.ylabel("Amplitud",fontsize=18)
plt.xlim(np.amin(ffe),np.amax(ffe))
plt.plot(omg_0*np.ones(int(np.amax(amp))),np.linspace(0.0, int(np.amax(amp)),int( np.amax(amp))) , 'g--',label='$\omega_0={0}$'.format(omg_0))
plt.legend(loc='upper right', shadow=True, fontsize='x-large')
plt.plot(ffe,amp, color='k')
plt.grid()

plt.subplot(2, 1, 2)
plt.xlabel("frecuencia de la fuerza externa $(\omega_d)$",fontsize=18)
plt.ylabel("Amplitud",fontsize=18)
plt.xlim(np.amin(ffe),np.amax(ffe))
plt.ylim(0,np.amax(amp)/4)
plt.plot(omg_0*np.ones(int(np.amax(amp))),np.linspace(0.0, int(np.amax(amp)),int( np.amax(amp))) , 'g--',label='$\omega_0={0}$'.format(omg_0))
plt.legend(loc='upper right', shadow=True, fontsize='x-large')
plt.plot(ffe,amp, color='k')
plt.grid()

# %% [markdown]
# Donde vemos que el máximo de la amplitud esta en la frecuencia de fuerza extrema que es igual a la frecuencia natural $\omega_d = \omega_0$. Donde:
#
# \begin{equation}
# Amplitud_{max}= Amplitud(\omega_0)=\frac{A}{\omega_0\mu} = 20
# \end{equation}
#
# Entre más grande sea la frecuencia de fuerza externa que la frecuencia natural  $\omega_d >> \omega_0$ más pequeña es la amplitud. Ademas, si no hay frecuencia de fuerza externa, el oscilador amortiguado no aumenta ni disminuye su amplitud, es decir, permanece constante.

# %% [markdown]
# #### b) Graficar la Fase de la solución como función de la frecuencia de la fuerza externa.
#
# La fase la podemos calcular con la siguiente expresión:
#
# \begin{equation}
# \delta =\tan^{-1} \left[ \frac{\mu\omega_d}{\omega_0^2 -\omega_d^2} \right]
# \end{equation}
#
# En la siguiente línea de código se define la expresión anterior con una función:

# %%
def fase(dat):
    omg = dat[0]  #frecuencia de la fuerza externa.
    mu = dat[1]  
    omg0 = dat[2] #frencuencia natural
    arg = np.divide(mu*omg,pow(omg0,2)-np.power(omg,2))
    return np.arctan(arg)

# %% [markdown]
# Entonces, calculamos la fase en función de la frecuemcia de fuerza externa "$ffe = \omega_d$":

# %%
ffe2 = np.linspace(-omg_0,omg_0, 10000) 
dats2 = np.array([ffe2,mu,omg_0]) 
fass = fase(dats2)
# Out:
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:5: RuntimeWarning: divide by zero encountered in true_divide
#   """

# %% [markdown]
# Nota: La función np.arctang devolverá valores entre $-\pi/2<\delta<\pi/2$ por lo que la moveré $\pi/2$ hacia arriba
#
# Y graficamos la funcón:

# %%
plt.figure(figsize=(8,8))
plt.title('(1.b) Fase Vs. frecuencia de la fuerza externa',fontsize = 28, color = '0', verticalalignment = 'baseline', horizontalalignment = 'center')
plt.xlabel("frecuencia de la fuerza externa $(\omega_d)$",fontsize=18)
plt.ylabel("Fase $(\delta)$",fontsize=18)
plt.plot(ffe2 + np.amax(ffe2),fass + np.amax(fass), color='k')
plt.axis('equal')
plt.grid()
plt.show()

# %% [markdown]
# #### c) Graficar el ángulo y la velocidad angular como función del tiempo para 2 condiciones iniciales distintas.

# %% [markdown]
# Usando la solución particular:
#
# \begin{equation}
# \theta_p(t)=\frac{A}{\sqrt{(\omega_0^2-\omega_d^2)^2 + \omega_d^2\mu^2}} \cos(\omega_dt-\delta)
# \end{equation}
#
# con $A=1$, $\omega_0 = 1$ y $\mu = 0.05$

# %% [markdown]
# Para encontrar una frecuencia de fuerza externa $\omega_d$ para que A sea igual a 1 dependera de las condiciones iniciales, de tal forma que:
#
# \begin{equation}
# \omega_d = \omega_0 \sqrt{\frac{\dot\theta(0)}{(\mu+\theta(0))+\dot\theta(0)}}
# \end{equation}
#
# donde $\theta(0)$ y $\dot\theta(0)$ son las condiciones iniciales.
#
# En la siguinete líniea de código defino la función para calcular $\omega_d$ con las condiciones iniciales:

# %%
def omega_d(omg0,mu,a,b):
    N_1 = b/((mu*a)+b)
    return pow(N_1,0.5)*omg0

# %% [markdown]
# Aqui definimos una función para calcular la solución particular $\theta(t)$ y $\dot\theta(t)$, donde:
#
# \begin{equation}
# \dot\theta_p(t)=\frac{A\omega_d}{\sqrt{(\omega_0^2-\omega_d^2)^2 + \omega_d^2\mu^2}} \sin(\omega_dt-\delta)
# \end{equation}
#
# Es la velocidad angular.

# %%
def sol_th(datos,A,t): # solución particular 
    omgd,mu,omg0= datos
    delta = fase(datos) #Usamos la función anterior para calcular la fase
    arg = pow( pow(pow(omg0,2)-pow(omgd,2),2)+pow(omgd*mu,2) ,0.5)
    ampl = A/arg
    return ampl*np.cos((omgd*t)-delta)

# %%
def dsol_th(datos,A,t):
    omgd,mu,omg0= datos
    delta = fase(datos) #Usamos la función anterior para calcular la fase
    arg = pow( pow(pow(omg0,2)-pow(omgd,2),2)+pow(omgd*mu,2) ,0.5)
    ampl = A/arg
    return -omgd*ampl*np.sin((omgd*t)-delta)

# %% [markdown]
# Calculamos la solución $\theta_1(t)$ y $\dot\theta_1(t)$ con condiciones iniciales $\theta_1(t=0)=\pi/18$ y $\dot\theta_1(t=0)=2\pi/50$ considerando que el ángulo inicial sea muy pequeño para que funcione la linealización a primer orden de la ecuación diferencial.

# %%
#condiciones iniciales (1) :
omg_01 , mu_1 , A = 1 , 0.05 , 1
ang_ini_1 = np.pi/18
dang_ini_1 = 2*np.pi/50
omgd_1 = omega_d(omg_01, mu_1, ang_ini_1, dang_ini_1)
datos_1 = np.array([omgd_1,mu_1,omg_01]) 
t_1 = np.linspace(0,100,500)
sol_th_1 =  sol_th(datos_1, A, t_1)
dsol_th_1 =  dsol_th(datos_1, A, t_1)

# %% [markdown]
# Ahora, calculamos una segunda la solución $\theta_2(t)$ y $\dot\theta_2(t)$ con condiciones iniciales $\theta_2(t=0)=\pi/15$ y $\dot\theta_2(t=0)=2\pi/10$.

# %%
#condiciones iniciales (2) :
omg_02 , mu_2 , A = 1 , 0.05 , 1
ang_ini_2 = np.pi/15
dang_ini_2 = 2*np.pi/5
omgd_2 = omega_d(omg_02,mu_2,ang_ini_2,dang_ini_2)
datos_2 = np.array([omgd_2,mu_2,omg_02]) 
t_2 = np.linspace(0,100,500)
sol_th_2 =  sol_th(datos_2, A, t_2)
dsol_th_2 =  dsol_th(datos_2, A, t_2)

# %% [markdown]
# Y graficamos las dos soluciones con diferentes condiciones iniciales en función del tiempo:

# %%
plt.figure(figsize=(20,10))
plt.title('(1.d) \Theta,\dot\Theta Vs t',fontsize = 18, color = '0', verticalalignment = 'baseline', horizontalalignment = 'center')
plt.subplot(2, 1, 1)
plt.ylabel('$\Theta$',fontsize=18)
plt.plot(t_1,sol_th_1,'g',label='$\Theta(t=0)_1={:.1f}$'.format(ang_ini_1*180/np.pi))
plt.plot(t_2,sol_th_2,'r',label='$\Theta(t=0)_2={:.1f}$'.format(ang_ini_2*180/np.pi))
plt.legend(loc='upper right', shadow=True, fontsize='x-large')
plt.grid()
plt.subplot(2, 1, 2)
plt.ylabel('$\dot\Theta$',fontsize=18)
plt.xlabel('tiempo', fontsize=18)
plt.plot(t_1,dsol_th_1,'g',label='$\dot\Theta(t=0)_1={:.2f}$'.format(dang_ini_1))
plt.plot(t_2,dsol_th_2,'r',label='$\dot\Theta(t=0)_2={:.2f}$'.format(dang_ini_2))
plt.legend(loc='upper right', shadow=True, fontsize='x-large')
plt.grid()

# %% [markdown]
# Podemos ver como se desfasan las soluciones para condiciones iniciales distintas. Es decir, tanto la frecuencia y amplitud del movimiento dependerán de la configuración inicial del sistema. De tal forma que la amplitud del movimiento será proporcional al ángulo inicial. La frecuencia cambiara de la misma manera.
#
# Ahora graficamos el espacio fase de las dos soluciones:

# %%
plt.figure(figsize=(6,6))
plt.title('(1.d) Espacio fase',fontsize = 28, color = '0', verticalalignment = 'baseline', horizontalalignment = 'center')
plt.xlabel('$\Theta$',fontsize=18)
plt.ylabel('$\dot\Theta$',fontsize=18)
plt.plot(sol_th_1,dsol_th_1,'g',label='$\Theta(0)_1={:.1f}$'.format(ang_ini_1*180/np.pi))
plt.plot(sol_th_2,dsol_th_2,'r',label='$\Theta(0)_2={:.1f}$'.format(ang_ini_2*180/np.pi))
plt.legend(loc='upper right', shadow=True, fontsize='x-large')
plt.axis('equal')
plt.grid()

# %% [markdown]
# La trayectoria que se forma en el espacio fase toma forma de un circulo ademas es una trayctoria cerrada. Esto se debe a que sólo estamos tomado la solución particular, es decir, aquella que,al transcurrir mucho tiempo, converge en un movimento periodico debido a una fuerza externa que se le aplica. El movimiento no parece tener un decrecimiento en la velocidad ya que el parametro de amortiguamiento $\mu$ es muy pequeño.

# %% [markdown]
# ### d) Graficar en el espacio fase las 2 trayectorias con condiciones iniciales distintas del inciso anterior.

# %% [markdown]
# Tomamos condiciones iniciales diferentea al inciso anteriro:
#
# $\theta(t=0)=\pi/25$ y $\dot\theta(t=0)=2\pi/38$

# %%
#condiciones iniciales (3) :
omg_03 , mu_3 , A_3 = 1 , 0.05 , 1
ang_ini_3 = np.pi/25
dang_ini_3 = 2*np.pi/94
omgd_3 = omega_d(omg_03,mu_3,ang_ini_3,dang_ini_3)
datos_3 = np.array([omgd_3,mu_3,omg_03]) 
t_3 = np.linspace(0,50,500)
sol_th_3 =  sol_th(datos_3, A_3, t_3)
dsol_th_3 =  dsol_th(datos_3, A_3, t_3)

# %% [markdown]
# $\theta(t=0)=\pi/46.6$ y $\dot\theta(t=0)=2\pi/94$

# %%
#condiciones iniciales (4) :
omg_04 , mu_4 , A_4 = 1 , 0.05 , 1
ang_ini_4 = np.pi/43.6
dang_ini_4 = 2*np.pi/94
omgd_4 = omega_d(omg_04,mu_4,ang_ini_4,dang_ini_4)
datos_4 = np.array([omgd_4,mu_4,omg_04]) 
t_4 = np.linspace(0,50,500)
sol_th_4 =  sol_th(datos_4, A_4, t_4)
dsol_th_4 =  dsol_th(datos_4, A_4, t_4)

# %% [markdown]
# Graficamos las 2 soluciones con diferentes condiciones iniciales en el espacio fase:

# %%
plt.figure(figsize=(6,6))
plt.ylabel('$\dot\Theta$',fontsize=18)
plt.xlabel('$\Theta$', fontsize=18)
plt.plot(sol_th_3, dsol_th_3 ,'g',label='$\Theta(0)_3 = {:.1f}$'.format(ang_ini_3*180/np.pi))
plt.plot(sol_th_4,dsol_th_4,'r',label='$\Theta(0)_4 = {:.1f}$'.format(ang_ini_4*180/np.pi))
plt.legend(loc='upper right', shadow=True, fontsize='x-large')
plt.axis('equal')
plt.grid()

# %% [markdown]
# Al igual que en el inciso anterior se forman trayectorias elipticas cerradas que a simple vista parecen circulos. El tamaño de estos depende de las condiciones iniciales, ya que, como se vio en el inciso anterior,  al incrementar o disminuir el ángulo inicial aumentara o disminuirá la amplitud de sus oscilaciones que serian los extremos laterales de la elipse.

# %% [markdown]
# ### e) Graficar en el espacio fase 2 trayectorias con 2 A's distintas, $\mu=0.05$ y la misma confición inicial.
#
# Usamos $A_3 = 0.23$, $A_4 = 2.4$ con condicione iniciales de $\theta(t=0)=\pi/20$ y $\dot\theta(t=0)=2\pi/30$

# %%
#condiciones iniciales (5) :
omg_05 , mu_5 , A_5 = 1 , 0.05 , 0.23
ang_ini_5 = np.pi/20
dang_ini_5 = 2*np.pi/30
omgd_5 = omega_d(omg_05,mu_5,ang_ini_5,dang_ini_5)
datos_5 = np.array([omgd_5,mu_5,omg_05]) 
t_5 = np.linspace(0,50,500)
sol_th_5 =  sol_th(datos_5, A_5, t_5)
dsol_th_5 =  dsol_th(datos_5, A_5, t_5)

# %%
#condiciones iniciales (5) :
omg_06 , mu_6 , A_6 = 1 , 0.05 , 2.4
ang_ini_6 = np.pi/43.6
dang_ini_6 = 2*np.pi/94
omgd_6 = omega_d(omg_06,mu_6,ang_ini_6,dang_ini_6)
datos_6 = np.array([omgd_6,mu_6,omg_06]) 
t_6 = np.linspace(0,50,500)
sol_th_6 =  sol_th(datos_6, A_6, t_6)
dsol_th_6 =  dsol_th(datos_6, A_6, t_6)

# %%
plt.figure(figsize=(6,6))
plt.ylabel('$\dot\Theta$',fontsize=18)
plt.xlabel('$\Theta$', fontsize=18)
plt.plot(sol_th_5, dsol_th_5 ,'g',label='$A_5 = {:.1f}$'.format(A_5))
plt.plot(sol_th_6,dsol_th_6,'r',label='$A_6 = {:.1f}$'.format(A_6))
plt.legend(loc='upper right', shadow=True, fontsize='x-large')
plt.axis('equal')
plt.grid()

# %% [markdown]
# La amplitud de la fuerza externa afectara al del movimiento al que converge el oscilador. Entre mayor sea la amplitud de la fuerza externa mayor será la amplitud de movimiento.

# %% [markdown]
# ### f) Graficar en el espacio fase 2 trayectorias con $2\mu's$ distintas, $A=1$ y la misma confición inicial.
#
# Usamos $\mu_5 = 5$, $\mu_6 = 0.23$ con condicione iniciales de $\theta(t=0)=\pi/15$ y $\dot\theta(t=0)=2\pi/20$

# %%
#condiciones iniciales (5) :
omg_06 , mu_6 , A_6 = 1 , 5 , 1
ang_ini_6 = np.pi/15
dang_ini_6 = 2*np.pi/(20)
omgd_6 = omega_d(omg_06,mu_6,ang_ini_6,dang_ini_6)
datos_6 = np.array([omgd_6,mu_6,omg_06]) 
t_6 = np.linspace(0,50,500)
sol_th_6 =  sol_th(datos_6, A_6, t_6)
dsol_th_6 =  dsol_th(datos_6, A_6, t_6)

# %%
#condiciones iniciales (6) :
omg_07 , mu_7 , A_7 = 1 , 0.8 , 1
ang_ini_7 = np.pi/15
dang_ini_7 = 2*np.pi/(20)
omgd_7 = omega_d(omg_07,mu_7,ang_ini_7,dang_ini_7)
datos_7 = np.array([omgd_7,mu_7,omg_07]) 
t_7 = np.linspace(0,50,500)
sol_th_7 =  sol_th(datos_7, A, t_7)
dsol_th_7 =  dsol_th(datos_7, A, t_7)

# %%
plt.figure(figsize=(6,6))
plt.ylabel('$\dot\Theta$',fontsize=18)
plt.xlabel('$\Theta$', fontsize=18)
plt.plot(sol_th_6, dsol_th_6 ,'g',label='$\mu={:.2f}$'.format(mu_6))
plt.plot(sol_th_7,dsol_th_7,'r',label='$\mu={:.2f}$'.format(mu_7))
plt.legend(loc='upper right', shadow=True, fontsize='x-large')
plt.axis('equal')
plt.grid()

# %% [markdown]
# Al tener el parametros de amortiguamiento $\mu$ grandes se aprecia mejor la forma eliptica de la trayctoria en el espacio fase. Al aumentar $\mu$ se ve como aumenta la exentricidad de la elipse, es decir, se hace más achatada. El achatamiento se debe a la perdida de velocidad, causada por la fricción con el medio, mientras el oscilador llega a cada extremo.

# %% [markdown]
# #### Graficas de la solución general
#
# Usando la solución:
# \begin{equation}
# \theta_p(t)=\frac{A}{\sqrt{(\omega_0^2-\omega_d^2)^2 + \omega_d^2\mu^2}} \cos(\omega_dt-\delta)
# \end{equation}
#
# Tomando: $A=1$, $\omega_0=1$, $\mu=0.05$
#
# Y al ser $\omega_0 > \mu^2/4$ la solución a la ecuación homogenea es un oscilador inframortiguado, es decir:
#
# \begin{equation}
# \theta_h(t) = B e^{\frac{-\mu t}{2}}\cos\left(\sqrt{1 - \frac{\mu^2}{4}} t + \delta\right)
# \end{equation}
#
# \begin{equation}
# \Rightarrow \theta(t) = \frac{1}{\sqrt{(1-\omega_d^2)^2 + \omega_d^2\mu^2}} \cos(\omega_dt+\delta) + B e^{\frac{-\mu t}{2}}\cos\left(\sqrt{1 - \frac{\mu^2}{4}} t + \delta\right)
# \end{equation}

# %%
def fase(dat):
    omg = dat[0]  #frecuencia de la fuerza externa.
    mu = dat[1]  
    omg0 = dat[2] #frencuencia natural
    arg = np.divide(mu*omg,pow(omg0,2)-pow(omg,2))
    return np.arctan(arg)

# %%
def B_c(datos,delta):
    omgd,mu,omg0,omg1,th_i,thp_i = datos
    N_1 = pow(pow(omg0**2 - omgd**2,2) + omgd**2*mu**2,0.5)
    N_2 = (th_i/(math.cos(delta))) - (thp_i*N_1)/(omgd*math.sin(delta))
    N_3 = 1 - (N_1/omgd)*((mu/(2*math.tan(delta)))+omg1)
    return (N_2/N_3)

# %%
def A_c(datos,delta,B):
    omgd,mu,omg0,omg1,th_i,thp_i= datos
    N_1 = pow(pow(omg0**2 - omgd**2,2) + omgd**2*mu**2,0.5)
    N_2 = (thp_i*N_1)/(omgd*math.sin(delta))
    N_3 = (N_1/omgd)*((mu/(2*math.tan(delta)))+omg1)
    return N_2 - (B*N_3)

# %%
def sol_theta_p(datos,A,B,delta,t):
    omg,mu,omg0,omg1,th_i,thp_i = datos
    arg_1 = pow( pow(pow(omg0,2)-pow(omg,2),2)+pow(omg*mu,2) ,0.5)
    ampl = A/arg_1
    homo = -mu*0.5*B*np.exp(-mu*t*0.5)*np.cos(omg1*t + delta) - omg1*B*np.exp(-mu*t*0.5)*np.sin(omg1*t + delta)
    return -ampl*omg*np.sin((omg*t)+delta)+ homo

# %%
def sol_theta(datos,A,B,delta,t):
    omg,mu,omg0,omg1,th_i,thp_i = datos
    arg_1 = pow( pow(pow(omg0,2)-pow(omg,2),2)+pow(omg*mu,2) ,0.5)
    ampl = A/arg_1
    homo = B*np.exp(-mu*t*0.5)*np.cos(omg1*t + delta)
    return ampl*np.cos((omg*t)+delta)+ homo

# %% [markdown]
# Condiciones iniciales de la primera trayectoria:

# %%
omg_01, mu1, th_i1= 0.8, 0.3, np.pi/9
omg_11 = pow(omg_01**2-mu1**2,0.5)
omg_d1 = omg_11/20
thp_i1 = omg_d1
datos_1 = np.array([omg_d1,mu1,omg_01,omg_11,th_i1,thp_i1])
delta_1 = fase(datos_1)
B_1 = B_c(datos_1,delta_1)
A_1 = A_c(datos_1,delta_1,B_1)

# %% [markdown]
# Condiciones iniciales de la segunda trayectoria:

# %%
omg_02, mu2, th_i2= 0.9, 0.5, np.pi/18
omg_12 = pow(omg_02**2-mu2**2,0.5)
omg_d2 = omg_12/4
thp_i2 = omg_d2
datos_2 = np.array([omg_d2,mu2,omg_02,omg_12,th_i2,thp_i2])
delta_2 = fase(datos_2)
B_2 = B_c(datos_2,delta_2)
A_2 = A_c(datos_2,delta_2,B_2)

# %%
t=np.linspace(0, 150, 10000)
tha_1 = sol_theta(datos_1,delta_1,A_1,B_1,t)
tha_P1 = sol_theta_p(datos_1,delta_1,A_1,B_1,t)
tha_2 = sol_theta(datos_2,delta_2,A_2,B_2,t)
tha_P2 = sol_theta_p(datos_2,delta_2,A_2,B_2,t)

plt.figure(figsize=(10,10))
plt.subplot(2, 1, 1)
plt.ylabel('$\Theta$',fontsize=18)
plt.plot(t,tha_1,'g',label='$\Theta_1$')
plt.plot(t,tha_2,'r',label='$\Theta_2$')
plt.legend(loc='upper right', shadow=True, fontsize='x-large')
plt.grid()
plt.subplot(2, 1, 2)
plt.ylabel('$\dot\Theta$',fontsize=18)
plt.xlabel('tiempo', fontsize=18)
plt.plot(t,tha_P1,'g',label='$\dot\Theta_1$')
plt.plot(t,tha_P2,'r',label='$\dot\Theta_2$')
plt.legend(loc='upper right', shadow=True, fontsize='x-large')
plt.grid()

plt.show()

# %%
omg_03, mu3, th_i3= 0.4, 0.1, np.pi/9 
omg_13 = pow(omg_03**2-mu3**2,0.5)
omg_d3 = omg_13/6
thp_i3 = omg_d3*1.5
datos_3 = np.array([omg_d3,mu3,omg_03,omg_13,th_i3,thp_i3])
delta_3 = fase(datos_3)
B_3 = B_c(datos_3,delta_3)
A_3 = A_c(datos_3,delta_3,B_3)

omg_04, mu4, th_i4= 1.8, 0.9, np.pi/16 
omg_14 = pow(omg_04**2-mu4**2,0.5)
omg_d4 = omg_14/1.5
thp_i4 = omg_d4/2
datos_4 = np.array([omg_d4,mu4,omg_04,omg_14,th_i4,thp_i4])
delta_4 = fase(datos_4)
B_4 = B_c(datos_4,delta_4)
A_4 = A_c(datos_4,delta_4,B_4)

t=np.linspace(0, 500, 10000)
tha_3 = sol_theta(datos_3,delta_3,A_3,B_3,t)
tha_P3 = sol_theta_p(datos_3,delta_3,A_3,B_3,t)
tha_4 = sol_theta(datos_4,delta_4,A_4,B_4,t)
tha_P4 = sol_theta_p(datos_4,delta_4,A_4,B_4,t)

# %%
plt.figure(figsize=(20,10))
plt.subplot(1, 2, 1)
plt.title('d) Espacio fase',fontsize = 28, color = '0', verticalalignment = 'baseline', horizontalalignment = 'center')
plt.ylabel('$\dot\Theta_1$',fontsize=18)
plt.xlabel('$\Theta_1$',fontsize=18)
plt.plot(tha_3,tha_P3,'g')
plt.grid()
plt.subplot(1, 2, 2)
plt.title('d) Espacio fase',fontsize = 28, color = '0', verticalalignment = 'baseline', horizontalalignment = 'center')
plt.ylabel('$\dot\Theta_2$',fontsize=18)
plt.xlabel('$\Theta_2$', fontsize=18)
plt.plot(tha_4,tha_P4,'r')
plt.grid()

# %% [markdown]
# ## 2. Ecuación no lineal no forzada sin amortiguamiento.
#
# La ecuación tiene la forma:
#
# \begin{equation}
# \ddot \theta + \omega_0^2 sin(\theta) = 0
# \end{equation}
#
# ### a) Para un ángulo inicial de 70 grados en reposo y una frecuencia natural unitaria, realiza una gráfica donde compares la solucion numérica del ángulo y su velocidad con aquella de la ecuación lineal usando las mismas condiciones iniciales.
#
# Usando :
#
# \begin{equation}
# \omega = \dot\theta
# \end{equation}
#
# Entonces tenemos una ecuaión para encontrar $\omega$:
#
# \begin{equation}
# \Rightarrow \dot\omega = - \omega_0^2 sin(\theta)
# \end{equation}
#
# Donde, $\omega$ es la velocida angular.
#
# Y así, encontrando $\omega$ podemos encontrar $\theta$ con la primera ecuación
#
# En las siguiente linea de codigo se usa el modulo de odeint en la libreria scipy para encontrar la solución numérica de la ecuación diferencial.
#
# Priemro definimos la función para calcular las soluciones $\omega$ y $\theta$ de la ecuación diferencial:

# %%
def fun_nolin (con_iniciales, t, omg_0, b ):
    theta, omega = con_iniciales
    return [omega, - omg_0**2*np.sin(theta)]

# %% [markdown]
# Usamos frecuencia natural unitaria: $\omega_0 = 1$. Para un ángulo inicial de 70 grados $\theta(t=0)=70$ y velocidad angular $\omega(t=0)=0$ ya que parte del reposo.

# %%
t = np.linspace(0, 50, 1000)
th_ini=70
dth_ini=0
b=0
omg_0=1
con_ini = [(th_ini*np.pi/180), dth_ini] # condiciones iniciales
sol_nolin_2a = odeint(fun_nolin, con_ini, t, args=(omg_0 , b))

# %% [markdown]
# Para comparar la solucion anterior con la de la ecuación linealizada, defino una nueva función que es solución a la ecuación lineal, es decir:
#
# \begin{equation}
# \theta(t) = A' \cos(\omega_0t - \delta)
# \end{equation}

# %%
def sol_lin(con_iniciales,omg0,t):
    th_ini , dth_ini = con_iniciales
    if th_ini == 0:
        delta = math.pi/2 
    else:
        delta = math.atan(-dth_ini/(th_ini*omg0)) 
    A = (th_ini)/math.cos(-delta)
    return A*np.cos(omg0*t- delta)

# %% [markdown]
# Y la velocidad angular será:
#
# \begin{equation}
# \dot\theta(t) = - A' \omega_0 \sin(\omega_0t-\delta)
# \end{equation}

# %%
def dsol_lin(con_iniciales,omg0,t):
    th_ini , dth_ini = con_iniciales
    if th_ini == 0:
        delta = math.pi/2 
    else:
        delta = math.atan(-dth_ini/(th_ini*omg0))  
    A = (th_ini)/math.cos(-delta)
    return -omg0*A*np.sin(omg0*t- delta)

# %% [markdown]
# Usamos las misma condiciones iniciales: frecuencia natural unitaria $\omega_0 = 1$ para un ángulo inicial de 70 grados $\theta(t=0)=70$ y velocidad angular $\omega(t=0)=0$ ya que parte del reposo.

# %%
sol_lin_2a = sol_lin(con_ini,omg_0,t) 
dsol_lin_2a = dsol_lin(con_ini,omg_0,t)

# %% [markdown]
# Comparamos las dos soluciones para el caso lineal y no linea en la siguiente gráfica:

# %%
# Theta Vs Tiempo
plt.figure(figsize=(15,3))
plt.title('(1.d) $\Theta$ Vs t',fontsize = 18, color = '0', verticalalignment = 'baseline', horizontalalignment = 'center')
plt.plot(t,sol_nolin_2a[:, 0],'g',label='$\Theta(t)_{no lineal}$') #solución NO lineal
plt.plot(t,sol_lin_2a,'r',label='$\Theta(t)_{lineal}$') #solución lineal 
plt.ylabel('$\Theta(t)$',fontsize=18)
plt.legend(loc='upper right', shadow=True, fontsize='x-large')
plt.grid()
plt.show()
# Velocidad angular Vs Tiempo
plt.figure(figsize=(15,3))
plt.title('(1.d) $\dot\Theta$ Vs t',fontsize = 18, color = '0', verticalalignment = 'baseline', horizontalalignment = 'center')
plt.plot(t, sol_nolin_2a[:, 1],'g',label='$\dot\Theta(t)_{no linieal}$' )
plt.plot(t,dsol_lin_2a,'r',label='$\dot\Theta(t)_{linieal}$')
plt.xlabel('$Tiempo$',fontsize=18)
plt.ylabel('$\dot\Theta(t)$',fontsize=18)
plt.legend(loc='upper right', shadow=True, fontsize='x-large')
plt.grid()
plt.show()

# %% [markdown]
# Podemos observar que la diferencia entre la soluciones de la ecuación lineal y no lineal va siendo cada vez más grande a tiempos mayores. Por lo que con una condición inicial $\theta(t=0)$ para ángulos grandes la solución a la ecuación lineal deja de ser precisa.

# %% [markdown]
# ### b) Construye el espacio fase para una frecuencia natural unitaria, usando trayectorias que partan del reposo con un ángulo inicial que vaya de -90 a 90 grados, en intervalos de 10 grados. Suma dos trayectorias que den vueltas, una encontra de las manecillas del reloj y otra a favor.

# %% [markdown]
# Usando el mismo modulo odein y la misma función del inciso anterior "fun_nolin" para relorver la ecuación no lineal para distintos ángulos que van de -90 a 90

# %%
th_i_2b = np.arange (-90,100,10) #Arreglo con todos los ángulos 
dth_i_2b = np.zeros(len(th_i_2b)) #Arreglo con todas las velocidades iniciales = 0
omg_0=np.ones(len(th_i_2b)) #Arreglo con todas las frecuencias naturales iguales a 1
t = np.linspace(0, 200, 10000)
b = 0
sol_2b_rel=[]
for i  in range(len(th_i_2b)):
    con_ini = [(th_i_2b[i]*np.pi/180) , dth_i_2b[i]]
    sol_2b_rel.append(odeint(fun_nolin, con_ini, t, args=(omg_0[i],b))) # el pow(-1,i) para crear trayectoria que caminen en sentido de las manesillas del reloj y en contra de ellas.

# %%
#graficamos:
plt.figure(figsize=(8,8))
plt.title('(2.b) Espacio fase',fontsize = 28, color = '0', verticalalignment = 'baseline', horizontalalignment = 'center')
for i  in range(len(th_i_2b)):
    plt.plot(sol_2b_rel[i][:, 0], sol_2b_rel[i][:, 1],label='$\Theta(t=0)={:.2f}$'.format(th_i_2b[i]))
plt.xlabel('$\Theta$',fontsize=18)
plt.ylabel('$\omega$',fontsize=18)
plt.legend()
plt.axis('equal')
plt.grid()
plt.show()

# %% [markdown]
# Para ángulos mayores la forma de elipse se nota un poco más para un mismo valor de $\mu=0.05$. Para ángulos iniciales iguales, pero, de signo contrario, las trayectoria se traslapan debido a que despues de cierto tiempo los dos osciladores tendran la misma amplitud y con misma velocidad angular.
#
# Ahora sumamos dos trayectorias que den vueltas, una en contra de las manecillas del reloj y otra a favor. La parametrización que se uso fue con el tiempo, cambiando el signo de este para cambiar la direccion del giro:

# %%
# soluciones con trayectorias en sentido antihorario.
sol_2b_antirel=[]
for i  in range(len(th_i_2b)):
    con_ini = [(th_i_2b[i]*np.pi/180) , dth_i_2b[i]]
    sol_2b_antirel.append(odeint(fun_nolin, con_ini, (-1)*t, args=(omg_0[i],b))) # el pow(-1,i) para crear trayectoria que caminen en sentido de las manesillas del reloj y en contra de ellas.

# %% [markdown]
# Se sumara la trayectoria con ángulo inicial de $\theta = - 90$ grados a favor de las manecillas del reloj a cada trayectoria de los diferentes ángulos per en contra de las manecillas del reloj y obtenemos lo siguiente:

# %%
plt.figure(figsize=(20,20))
for j in range(19):
    plt.title('(2.b) Espacio fase',fontsize = 10, color = '0', verticalalignment = 'baseline', horizontalalignment = 'center')
    plt.subplot(10, 4, j+1)
    plt.plot(sol_2b_rel[0][:, 0] + sol_2b_antirel[j][:, 0], sol_2b_rel[0][:, 1] + sol_2b_antirel[j][:, 1],'k,',label='$\Theta(t=0)={:.2f}$'.format(th_i_2b[j] ))
    plt.xlabel('$\Theta$',fontsize=10)
    plt.ylabel('$\dot\Theta$',fontsize=10)
    plt.axis('equal')
    plt.legend()
    plt.grid()

plt.show()

# %% [markdown]
# La forma de estos dibujos se entiende mejor con la primera gráfica de arriba. Al sumar las soluciones de forma horaria y antihoraria mientras van avanzando de forma independiente, la velocidad de una es positiva y la otra es negativa, por lo que al sumarlas se cancelan y por eso no hay movimiento en el eje $\dot\theta$ pero si en el eje $\theta$ porque viajan en el mismo sentido. Las demas graficas son una variación de este mismo proceso.

# %% [markdown]
# ## 3.- Ecuación no lineal amortiguada no forzada.
#
# ### a) Utiliza un parametro de amortiguamiento de 0.02, la frecuencia natural unitaria y observa cómo el espacio fase se distorciona. Compara cada trayectoria del inciso b) del ejercio anterior con este caso amortiguado

# %% [markdown]
# La ecuación del oscilador armonico amortiguado es la siguiente:
#
# \begin{equation}
# \ddot \theta + 2\beta \dot\theta + \omega_0^2 sin(\theta) = 0
# \end{equation}
#
# donde: $\beta$ es el parametro de amortiguamiento.
#
# Se usara la misma fución con el comando 'odeint' con $\mu \neq 0$

# %%
def fun_nolin_amor (con_iniciales, t, omg_0, mu):
    theta, omega = con_iniciales
    return [omega, -mu*omega - omg_0**2*np.sin(theta)]

# %%
th_i_3a = np.arange (-90,100,10) # 10 grados iniciales diferentes que van desde -90 a 90 para ser comparados con el inciso anterior 
dth_i_3a = 0 # cada caso comenzará en el reposo
omg_0 = 1 # 
t = np.linspace(0,200, 10000)
mu_3a=0.02
sol_3a=[]
for i  in range(len(th_i_3a )):
    con_ini = [(th_i_3a[i]*np.pi/180), dth_i_3a]
    sol_3a.append(odeint(fun_nolin_amor, con_ini, t, args=(omg_0,mu_3a)))

# %% [markdown]
# Graficamos el espacio fase:

# %%
plt.figure(figsize=(8,8))
plt.title('(3.a) Espacio fase',fontsize = 28, color = '0', verticalalignment = 'baseline', horizontalalignment = 'center')
plt.plot(sol_3a[0][:, 0], sol_3a[0][:, 1],'g' )
plt.xlabel('$\Theta$',fontsize=18)
plt.ylabel('$\omega$',fontsize=18)
plt.axis('equal')
plt.grid()
plt.show()

# %% [markdown]
# El espacio fase muestra como va diminuyendo la velocidad angular del oscilador y la amplitud de su movimiento.
#
# Ahora comparamos las soluciones vs tiempo del caso amortiguado y no amortiguado para casa condición inicial:

# %%
plt.figure(figsize=(20,20))
for j in range(19):
    plt.subplot(9, 3, j+1)
    plt.plot(t,sol_3a[j][:, 0],'g',label='$\Theta(t=0)={:.2f},\mu=0.02$'.format(th_i_3a[j]))
    plt.plot(t,sol_2b_rel[j][:, 0],'y',label='$\Theta(t=0)={:.2f},\mu=0.00$'.format(th_i_2b[j]))
    plt.xlabel('t')
    plt.ylabel('$\Theta$')
    plt.legend()
    plt.grid()

# %% [markdown]
# Al igual que en el espacio fase, se observa cómo la amplitud del movimiento disminuye para el caso amortiguado. Al mirar más de cerca, se puede observar que la frecuencia diminuye mientras pasa el tiempo, en otras palabras, la velocidad angular baja.
#
# Tambien comparamos el espacio fase para las trayectorias amortiguadas y no amortiguadas para cada condicion inicial.

# %%
plt.figure(figsize=(20,20))
for j in range(19):
    plt.subplot(9, 5, j+1)
    plt.xlim(np.amin(sol_2b_rel[0][:, 0]),np.amax(sol_2b_rel[0][:, 0]))
    plt.ylim(np.amin(sol_2b_rel[0][:, 1]),np.amax(sol_2b_rel[0][:, 1]))
    plt.plot(sol_3a[j][:, 0],sol_3a[j][:, 1],'g',label='$\mu=0.02$')
    plt.plot(sol_2b_rel[j][:, 0],sol_2b_rel[j][:, 1],'y',label='$\mu=0.00$')
    plt.xlabel('$\Theta$')
    plt.ylabel('$\dot\Theta$')
    plt.axis('equal')
    plt.legend()
    plt.grid()

# %% [markdown]
# Cada trayectoria en el espacio fase parece decaer de la misma forma para cada condicion inicial con $\dot\theta(0) = 0$ y diferentes ángulos $\theta(0)$. La forma de las espiral es la misma.

# %% [markdown]
# ## 4.- Ecuación no lineal completa.
#
# ### a) usando $\mu = 3\pi/2$, $\omega=2\pi$, $\omega_0 = 3\pi$,  grafica la solución para cinco casos de $A$ alrededor de $1.05$. Qué pasa con las soluciones. ¿Qué ocurre si $A=2$?
#
# \begin{equation}
# \ddot \theta + \mu \dot\theta + sin(\theta) = Acos(\omega_d t)
# \end{equation}
#
# Usando el mismo proceso para la ecuación no forzada:
#
# Usando :
#
# \begin{equation}
# \omega = \dot\theta
# \end{equation}
# \begin{equation}
# \phi = \omega_d t
# \end{equation}
#
# Entonces tenemos una ecuaión para encontrar $\omega$:
#
# \begin{equation}
# \Rightarrow \dot \omega = - \mu \omega - sin(\theta) + Acos(\phi)
# \end{equation}
#
# Donde, $\omega$ es la velocida angular.
#
# Y así, encontrando $\omega$ podemos encontrar $\theta$ con la primera ecuación:

# %%
def fun_com(con_ini,t,mu,omg_0,A,omg_d):
    theta, omega, phi = con_ini 
    return [omega, -mu*omega - pow(omg_0,2)*np.sin(theta) + A * np.cos(phi),omg_d]

# %%
t = np.arange(0, 5.0, 0.001)
mu = 3*np.pi/2
omg_0 = 3*np.pi
omg_d = 2*np.pi
th_i = -np.pi/2
dth_i = 3*np.pi
phi = 0
con_ini =[th_i,dth_i,phi]
sol_4a = []
A = []
for i in range (6):
    A.append(float(input('Valor de A = ')))
    sol_4a.append(odeint(fun_com,con_ini,t,args = (mu,omg_0,A[i],omg_d)))
# Out:
# Valor de A = 1.05
# Valor de A = 1.06
# Valor de A = 1.07
# Valor de A = 1.08
# Valor de A = 1.09
# Valor de A = 2

# %%
plt.figure(figsize=(20,5))
for j in range(6):
    plt.plot(t,sol_4a[j][:, 0],label='$A={0}$'.format(A[j]))
    plt.xlim(np.amin(t),np.amax(t))
    plt.legend()
plt.grid()
plt.show()
plt.figure(figsize=(20,5))
plt.ylim(-0.1,0.1)
for j in range(6):
    plt.plot(t,sol_4a[j][:, 0],label='$A={0}$'.format(A[j]))
    plt.xlim(0,3)
    plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# ¿Qué pasa con las soluciones?
#
# Las soluciones alrededor de $A=1.05$ son muy parecidas entres si. Hay poca diferencia entre sus amplitudes y no parecen estar desfasadas.
#
# ¿Qué ocurre si $A=2$?
#
# En este caso si se observa una diferencia significativa entre las amplitudes de las soluciones (con A alrededor de 1.05), pero tampoco parece estar desfasada. Tan sólo aumenta su amplitud significativamente.

# %% [markdown]
# ###  b) Obten las trayectorias en el espacio fase de los casos del inciso anterior.

# %%
plt.figure(figsize=(20,20))
for j in range(len(sol_4a)):
    plt.subplot(3, 3, j+1)
    plt.title('Espacio fase',fontsize = 10, color = '0', verticalalignment = 'baseline', horizontalalignment = 'center')
    plt.plot(sol_4a[j][:, 0],sol_4a[j][:, 1],label='$A={0}$'.format(A[j]))
    plt.xlabel('$\Theta$')
    plt.ylabel('$\dot\Theta$')
    plt.legend(loc='upper right', shadow=True, fontsize='x-large')
    plt.grid()

# %% [markdown]
# La solución converge en una trayctoria eliptica en el espcaio fase con cierta amplitud.

# %% [markdown]
# ### BONUS: obtener un diagrama de bifurcación para esta ecuación no lineal. Busca información en la red para ver cómo hacerlo.

# %% [markdown]
# Usando la misma función del inciso anterior pero cambiando las condiciones iniciales y los parametros:

# %%
def fun_bonus (con_iniciales, t, beta, omg_0, A, omg_d):
    theta, omega, phi = con_iniciales
    return [omega, -2*beta*omega - omg_0**2*np.sin(theta) + A*omg_0**2*np.cos(phi),omg_d]

# %% [markdown]
# Escojemos los parametros: $\omega_0 = 3\pi$, $\beta = \frac{3}{4} \pi$, $\omega_d = 2\pi$
#
# Con condiciones iniciales : $\theta(0) = -\frac{\pi}{2}$,  $\dot\theta(0) = 0$ y $\phi = 0$

# %%
th_amp = []
t = np.linspace(500,600, 100)
dth_5i = 0
phi_5i = 2*np.pi
th_5i = -np.pi/2
omg_d = 2*np.pi
omg_0 = 3*np.pi
beta_5a = 3*np.pi/4
A_5a = np.arange(1.06,1.09,0.0001)
con_iniciales = [th_5i, dth_5i, phi_5i]
for i in range(len(A_5a)):
    sol_5a = (odeint(fun_bonus, con_iniciales, t, args=(beta_5a,omg_0,A_5a[i],omg_d)))
    th_amp.append(np.amax(sol_5a[1::,0])-np.amin(sol_5a[1::,0]))
    sol_5a = []

# %%
plt.figure(figsize=(20,5))
plt.plot(A_5a,th_amp,'k.')
plt.title('Diagrama de Bifurcación',fontsize = 20, color = '0', verticalalignment = 'baseline', horizontalalignment = 'center')
plt.xlabel("Amplitud de la fuerza externa (A)")
plt.ylabel("Amplitud de solución  $\Theta$")
plt.grid()
plt.show()
